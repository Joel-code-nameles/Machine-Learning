# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %%
system = pd.read_csv('ghana_school_fees_data.csv')
system
# Out:
#    School Name  Location  Students  Teachers  Facilities    Level  \
# 0    School 84  Takoradi       537        21           3      JHS
# 1    School 54     Accra       363        28           6      JHS
# 2    School 71  Takoradi       382        32           7  Primary
# 3    School 46  Takoradi       126        24           7      JHS
# 4    School 45     Accra       325        37           9      JHS
# ..         ...       ...       ...       ...         ...      ...
# 95   School 61   Sunyani       420        34           7      JHS
# 96   School 72    Tamale       363        38           9      JHS
# 97   School 15     Accra       593        23          11      JHS
# 98   School 93     Accra       499        37           9  Primary
# 99   School 52  Takoradi       241        14           7      SHS
#
#     Years Running    Fee
# 0              10   7643
# 1              26   9166
# 2               7   9190
# 3              14   7711
# 4              26  10891
# ...

# %%
system.info()
system.dropna(inplace = True)
system
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   School Name    100 non-null    object
#  1   Location       100 non-null    object
#  2   Students       100 non-null    int64
#  3   Teachers       100 non-null    int64
#  4   Facilities     100 non-null    int64
#  5   Level          100 non-null    object
#  6   Years Running  100 non-null    int64
#  7   Fee            100 non-null    int64
# dtypes: int64(5), object(3)
# memory usage: 6.4+ KB
#    School Name  Location  Students  Teachers  Facilities    Level  \
# 0    School 84  Takoradi       537        21           3      JHS
# 1    School 54     Accra       363        28           6      JHS
# 2    School 71  Takoradi       382        32           7  Primary
# 3    School 46  Takoradi       126        24           7      JHS
# ...

# %%
system.drop_duplicates(inplace = True)
system
# Out:
#    School Name  Location  Students  Teachers  Facilities    Level  \
# 0    School 84  Takoradi       537        21           3      JHS
# 1    School 54     Accra       363        28           6      JHS
# 2    School 71  Takoradi       382        32           7  Primary
# 3    School 46  Takoradi       126        24           7      JHS
# 4    School 45     Accra       325        37           9      JHS
# ..         ...       ...       ...       ...         ...      ...
# 95   School 61   Sunyani       420        34           7      JHS
# 96   School 72    Tamale       363        38           9      JHS
# 97   School 15     Accra       593        23          11      JHS
# 98   School 93     Accra       499        37           9  Primary
# 99   School 52  Takoradi       241        14           7      SHS
#
#     Years Running    Fee
# 0              10   7643
# 1              26   9166
# 2               7   9190
# 3              14   7711
# 4              26  10891
# ...

# %%
plt.hist(system['Fee'], bins = 10,color = 'black')
x = system['Students']

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(x, system['Fee'])

def fun(x):
    return slope * x + intercept

model = list(map(fun,x))

# %%
plt.scatter(x,system['Fee'],marker = 'x',color = 'black')
plt.plot(x,model,color = 'green')

# %%
hunstudents = fun(100)
thunstudents = fun(200)
thrhundredstudents = fun(300)
fhundredstudents = fun(100)
print(f'The revenue for a 100 students is {hunstudents}')
print(f'The revenue for a 200 students is {thunstudents}')
print(f'The revenue for a 300 students is {thrhundredstudents}')
print(f'The revenue for a ? students is {fhundredstudents}')
# Out:
# The revenue for a 100 students is 7871.61302114752
# The revenue for a 200 students is 8414.566280098998
# The revenue for a 300 students is 8957.519539050474
# The revenue for a ? students is 6.032813982316932e+23
